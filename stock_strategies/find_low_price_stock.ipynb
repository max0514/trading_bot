# %%
import finlab
from finlab import data
import pandas as pd
import datetime as dt
import numpy as np
import math
from dotenv import load_dotenv
import os
import time
from finlab.backtest import sim
def config():
    load_dotenv()


    
config()

finlab.login(str(os.getenv('FINLAB_API')))
# Out:
# 輸入成功!

# %%
price_df = data.get('etl:adj_open')
price_df
# Out:
# Due to your status as a free user, the most recent data has been shortened or limited.
# Daily usage: 99.2 / 500 MB - etl:adj_open
# symbol      0015        0050       0051        0052       0053       0054
# date
# 2013-01-02  7.55   54.000000  25.750000   32.300000  23.300000  19.500000  \
# 2013-01-03  7.64   54.900000  26.200000   32.760000  23.290000  19.400000
# 2013-01-04  7.60   54.850000  26.120000   32.400000  23.120000  19.400000
# 2013-01-07  7.60   54.550000  25.900000   32.120000  22.900000  19.350000
# 2013-01-08  7.60   54.000000  25.840000   32.000000  22.900000  19.210000
# ...          ...         ...        ...         ...        ...        ...
# 2020-12-25   NaN  150.576957  54.571764  136.612141  72.902401  35.397279
# 2020-12-28   NaN  150.513743  54.685825  135.973767  72.837714  35.256966
# 2020-12-29   NaN  151.778033  55.737719  137.888890  73.290524  35.588616
# 2020-12-30   NaN  151.714818  55.623659  137.888890  73.613960  35.588616
# ...

# %%
df = price_df

q1 = df.quantile(0.10)
q2 = df.quantile(0.5)  # This is the median
q3 = df.quantile(0.75)

# Filter data for each quantile section
section1 = df[df <= q1]
section2 = df[(df > q1) & (df <= q2)]
section3 = df[(df > q2) & (df <= q3)]
section4 = df[df > q3]
section1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/max/Desktop/python_codes/trading_bot/stock_strategies/find_low_price_stock.ipynb Cell 3 line 8
#       <a href='vscode-notebook-cell:/Users/max/Desktop/python_codes/trading_bot/stock_strategies/find_low_price_stock.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> q3 = df.quantile(0.75)
#       <a href='vscode-notebook-cell:/Users/max/Desktop/python_codes/trading_bot/stock_strategies/find_low_price_stock.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> # Filter data for each quantile section
# ----> <a href='vscode-notebook-cell:/Users/max/Desktop/python_codes/trading_bot/stock_strategies/find_low_price_stock.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> section1 = df[df <= q1]
# ...
